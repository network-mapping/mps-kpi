# %%
import os
import re
import calendar
import yaml
import numpy as np
import pandas as pd
from glob import glob
from datetime import datetime

all_codes = r'(^NM[CILPG][PX][0-9]+)'
project_codes = r'(^NM[ACIL]P[0-9]+)'

input_folder = r'finance_reports'
config = yaml.load(open('config.yaml', "r"), Loader=yaml.FullLoader)
excel_header_row = 5
project_pattern = re.compile(project_codes)
report_dateformat = '%B %Y'
PROFIT_AND_LOSS = 'profit and loss'


def get_currency(company_name):

    if 'companies' not in config.keys():
        raise ValueError('No companies definied in config') 

    for k, v in config['companies'].items():
        
        if 'name' not in v.keys():
            raise ValueError(f'Company has no name: "{k}"')
        if 'currency' not in v.keys():
            raise ValueError(f'Company has no currency: "{k}"')
        
        if v['name'].lower() == company_name.lower():
            return v['currency']

    raise ValueError(f'Could not find "{company_name}" in config')
    

def get_conversion_rate(company_name, year, month):

    if 'exchange_rates' not in config.keys():
        raise ValueError('No exchange_rates definied in config') 

    for v in config['exchange_rates']:
        
        if 'year' not in v.keys():
            raise ValueError(f'Year missing from exchange_rate item: "{v}"')
        if 'month' not in v.keys():
            raise ValueError(f'Month missing from exchange_rate item: "{v}"')
            
        if str(v['year']) == year:
            if str(v['month']).lower() == month:
                currency = get_currency(company_name)
                if currency not in v.keys():
                    raise ValueError(f'"{currency}" not found in excahnge_rate item: "{v}"')
                return v[currency], currency
                
    raise ValueError(f'Could not find conversion rate for "{company_name}" on "{date.strftime(report_dateformat)}" in config')


def get_mps_category(cost):

    if 'cost_mapping' not in config.keys():
        raise ValueError('No cost_mapping definied in config') 

    for category, v in config['cost_mapping'].items():
        if cost.lower() in [x.lower() for x in v]:
            return category

    raise ValueError(f'Found unmapped cost project cost: "{cost}" - add this mapping to the config.')


def is_p_and_l_report(path):

    # get the company name, report type and date - ignore if not a p&l
    df = pd.read_excel(path, header=None)
    report = str(df.iloc[1, 0]).lower()

    return report == PROFIT_AND_LOSS


def get_mps_project_categories(df):

    # check all the project cost columns are mapped
    try:
        start_project_costs = np.nonzero(df.columns=='projects')[0][0] + 1
    except IndexError:
        raise ValueError(f'Could not find "projects" in costs categories')
    try:
        end_project_costs = np.nonzero(df.columns=='total projects')[0][0]
    except IndexError:
        raise ValueError(f'Could not find "total projects" in costs categories')
    categories = [[cost, get_mps_category(cost)] for cost in df.columns[start_project_costs:end_project_costs]]

    return pd.DataFrame(categories, columns=['finance', 'mps'])


def get_mps_income_categories(df):

    # check all the project cost columns are mapped
    try:
        start_income = np.nonzero(df.columns=='income')[0][0] + 1
    except IndexError:
        raise IndexError(f'Could not find "income" in costs categories')
    try:
        end_income = np.nonzero(df.columns=='total income')[0][0]
    except IndexError:
        raise IndexError(f'Could not find "total income" in costs categories')
    categories = [[cost, get_mps_category(cost)] for cost in df.columns[start_income:end_income]]

    return pd.DataFrame(categories, columns=['finance', 'mps'])


# drop columns that are not project costs or income and merge into the mps categories
def get_mps_columns(df):

    mps_project_categories = get_mps_project_categories(df)  # check all the project cost columns are mapped
    try:
        mps_income_categories = get_mps_income_categories(df)  # check all the project cost columns are mapped
    except IndexError:
        mps_income_categories = pd.DataFrame([], columns=['finance', 'mps'])

    # merge the columns by the mps group
    finance_columns = pd.concat([mps_project_categories.finance, mps_income_categories.finance]).values
    mps_columns = pd.concat([mps_project_categories.mps, mps_income_categories.mps]).values
    df = df[finance_columns].T
    df['mps_code'] = mps_columns
    df = df.groupby('mps_code').sum().T

    return df


def get_date(val):

    if re.match(r'^[1-9]+-[0-9]+ [a-zA-Z]+, 20[2-9][0-9]$', val):  # 'day-day month, year'
        tmp = re.split(',| |-', val)
        date = datetime.strptime(f'{tmp[-3]} {tmp[-1]}', report_dateformat)
        day = tmp[1]   
        
    elif re.match(r'^[a-zA-Z]+ [1-9]+-[0-9]+, 20[2-9][0-9]$', val):   # 'month day-day, year'
        tmp = re.split(',| |-', val)
        date = datetime.strptime(f'{tmp[0]} {tmp[-1]}', report_dateformat)
        day = tmp[2] 
        
    elif re.match(r'^[a-zA-Z]+ 20[2-9][0-9]$', val):  # 'month year'
        date = datetime.strptime(val, report_dateformat)
        day = calendar.monthrange(date.year, date.month)[1]
        
    year = date.strftime('%Y')
    month = date.strftime('%B').lower()
        
    return year, month, day
                

def import_profit_and_loss_report(path):

    # get the company name, report type and date - ignore if not a p&l
    df = pd.read_excel(path, header=None)
    company_name = str(df.iloc[0, 0]).lower()
    report = str(df.iloc[1, 0]).lower()

    if report != PROFIT_AND_LOSS:
        raise ValueError(f'"{path}" is not the expected format for a profit and loss report')

    year, month, day = get_date(df.iloc[2, 0])

    # now just get the data
    df = pd.read_excel(path, header=excel_header_row-1, index_col=0)

    # get rid of columns that do not have a project code
    # ignore the final row and the empty rows before it 
    # final row is something like: 'Monday, Jul 10, 2023 01:44:15 pm GMT+1 - Accrual Basis'
    project_columns = [column for column in df.columns if project_pattern.match(column)]
    df = df[project_columns][:-1].T
    df.columns = [str(x).lower().lstrip() for x in df.columns]

    # drop columns that are not project costs or income and merge into the mps categories
    df = get_mps_columns(df)
    
    # parse out the project code and name and add them back in as seperate columns
    projec_codes_and_names = [project_pattern.split(project)[1:] for project in df.index]  
    tmp = pd.DataFrame(projec_codes_and_names, columns=['code', 'name'])  

    # get the exchange rate and convert to GBP
    rate, currency = get_conversion_rate(company_name, year, month)
    df[df.select_dtypes(include=['number']).columns] *= rate

    # add in the dataframe specific information to the columns
    df.insert(0, 'Project Name', tmp.name.values)
    df.insert(0, 'Project Code', tmp.code.values)
    df.insert(0, 'Conversion Rate', rate)
    df.insert(0, 'Converted From', currency)
    df.insert(0, 'Currency', 'GBP')
    df.insert(0, 'Year', year)
    df.insert(0, 'Month', month)
    df.insert(0, 'Day', day)
    df.insert(0, 'Report', report)
    df.insert(0, 'Company', company_name)

    print(f'Parsed {company_name} {report} {month} {year} using exchange rate {rate}')

    return df

def get_mps_report(folder):
    # parse all the xls files in a folder
    reports = []
    for path in glob(os.path.join(folder, '*.xlsx')):
        if is_p_and_l_report(path):
            try:
                reports.append(import_profit_and_loss_report(path))
            except Exception as e:
                print(f'Unexpected error with report: {path} - {e}')
                raise e
        else:
            print(f'WARNING: Ignoring "{path}", format does not match profit and loss report.')

    return pd.concat(reports).fillna(0)
    

df = get_mps_report(input_folder)
df.to_csv('result.csv')
display(df)
# Out:
# Parsed network mapping corp profit and loss july 2023 using exchange rate 0.58
# Parsed network mapping corp profit and loss june 2023 using exchange rate 0.58
# Parsed network mapping inc profit and loss july 2023 using exchange rate 0.76
# Parsed network mapping inc profit and loss june 2023 using exchange rate 0.76
# Parsed network mapping limited profit and loss july 2023 using exchange rate 1.0
# Parsed network mapping limited profit and loss june 2023 using exchange rate 1.0
# Parsed network mapping pty ltd profit and loss july 2023 using exchange rate 0.52
# Parsed network mapping pty ltd profit and loss june 2023 using exchange rate 0.52
# WARNING: Ignoring "finance_reports\PM Weekly Report 10th July.xlsx", format does not match profit and loss report.
# mps_code                                                   Company  \
# NMCP23017 HONI 2023                           network mapping corp
# NMCP22118 Altalink Bull trail                 network mapping corp
# NMIP23020 FPL Tx Spring 2023                  network mapping corp
# NMCP23017 HONI 2023                           network mapping corp
# NMIP23042 NGUS TLE 2023                        network mapping inc
# NMIP23035 NYPA Group B                         network mapping inc
# NMIP23019 GPC SoCo VM 2023                     network mapping inc
# NMIP23056 APC SoCo VM 2023                     network mapping inc
# NMCP22118 ALtalink Bull Wind                   network mapping inc
# NMIP23005 Ameren Spring 2023                   network mapping inc
# NMIP22135 Avangrid NYSEG RGE                   network mapping inc
# NMIP23014 Avangrid                             network mapping inc
# NMIP23020 FPL Tx Spring 2023                   network mapping inc
# NMCP23017 HONI 2023                            network mapping inc
# NMIP23027 LGE Spring 2023                      network mapping inc
# NMIP23016 LS Power                             network mapping inc
# NMIP23060 Minnkota 2023                        network mapping inc
# NMIP22126 NGUS Indian River-Lyme Junction      network mapping inc
# NMIP23042 NGUS TLE 2023                        network mapping inc
# NMIP22035 NYPA Group A 2022                    network mapping inc
# NMIP23035 NYPA Group B                         network mapping inc
# NMIP23019 GPC SoCo VM 2023                     network mapping inc
# NMIP23056 APC SoCo VM 2023                     network mapping inc
# NMAP23006 Transgrid 2023                       network mapping inc
# NMIP23026 Xcel Energy SPS 2023 HB              network mapping inc
# NMIP23028 Xcel SPC                             network mapping inc
# NMIP22135 Avangrid NYSEG RGE               network mapping limited
# NMIP23016 LS Power                         network mapping limited
# NMIP23042 NGUS TLE 2023                    network mapping limited
# NMAP23006 Transgrid-NMA                    network mapping limited
# NMIP23028 Xcel SPC                         network mapping limited
# NMCP22118 ALtalink Bull Wind               network mapping limited
# NMIP23005 Ameren                           network mapping limited
# NMIP22135 Avangrid NYSEG RGE               network mapping limited
# NMIP23014 Avangrid Maine                   network mapping limited
# NMLP23069 Baker Hicks Dunoon               network mapping limited
# NMIP23020 FPL Tx Spring 2023               network mapping limited
# NMCP23017 HONI 2023                        network mapping limited
# NMIP23027 LGE Spring 2023                  network mapping limited
# NMIP23016 LS Power                         network mapping limited
# NMIP23060 Minnkota 2023                    network mapping limited
# NMLP23034 NGUK                             network mapping limited
# NMIP23029 NGUS E5-F6 Mapping               network mapping limited
# NMIP23042 NGUS TLE 2023                    network mapping limited
# NMIP22035 NYPA-NMI                         network mapping limited
# NMIP22135 Avangrid NYSEG RGE-NMI           network mapping limited
# NMIP23005 Ameren-NMI                       network mapping limited
# NMIP23020 FPL TX Spring 2023-NMI           network mapping limited
# NMAP23006 Transgrid-NMA                    network mapping limited
# NMIP22035 NYPA Group A 2022                network mapping limited
# NMIP23035 NYPA Group B                     network mapping limited
# NMIP23019 GPC SoCo VM 2023                 network mapping limited
# NMIP23056 APC SoCo VM 2023                 network mapping limited
# NMLP23057 SSE Fort Augustus                network mapping limited
# NMAP23006 Transgrid 2023                   network mapping limited
# NMIP23026 Xcel Energy SPS 2023 HB          network mapping limited
# NMIP23028 Xcel SPC                         network mapping limited
# NMAP23006 Transgrid 2023                   network mapping pty ltd
# NMAP23006 Transgrid 2023                   network mapping pty ltd
#
# mps_code                                            Report Day Month  Year  \
# NMCP23017 HONI 2023                        profit and loss  10  july  2023
# NMCP22118 Altalink Bull trail              profit and loss  30  june  2023
# NMIP23020 FPL Tx Spring 2023               profit and loss  30  june  2023
# NMCP23017 HONI 2023                        profit and loss  30  june  2023
# NMIP23042 NGUS TLE 2023                    profit and loss  10  july  2023
# NMIP23035 NYPA Group B                     profit and loss  10  july  2023
# NMIP23019 GPC SoCo VM 2023                 profit and loss  10  july  2023
# NMIP23056 APC SoCo VM 2023                 profit and loss  10  july  2023
# NMCP22118 ALtalink Bull Wind               profit and loss  30  june  2023
# NMIP23005 Ameren Spring 2023               profit and loss  30  june  2023
# NMIP22135 Avangrid NYSEG RGE               profit and loss  30  june  2023
# NMIP23014 Avangrid                         profit and loss  30  june  2023
# NMIP23020 FPL Tx Spring 2023               profit and loss  30  june  2023
# NMCP23017 HONI 2023                        profit and loss  30  june  2023
# NMIP23027 LGE Spring 2023                  profit and loss  30  june  2023
# NMIP23016 LS Power                         profit and loss  30  june  2023
# NMIP23060 Minnkota 2023                    profit and loss  30  june  2023
# NMIP22126 NGUS Indian River-Lyme Junction  profit and loss  30  june  2023
# NMIP23042 NGUS TLE 2023                    profit and loss  30  june  2023
# NMIP22035 NYPA Group A 2022                profit and loss  30  june  2023
# NMIP23035 NYPA Group B                     profit and loss  30  june  2023
# NMIP23019 GPC SoCo VM 2023                 profit and loss  30  june  2023
# NMIP23056 APC SoCo VM 2023                 profit and loss  30  june  2023
# NMAP23006 Transgrid 2023                   profit and loss  30  june  2023
# NMIP23026 Xcel Energy SPS 2023 HB          profit and loss  30  june  2023
# NMIP23028 Xcel SPC                         profit and loss  30  june  2023
# NMIP22135 Avangrid NYSEG RGE               profit and loss  10  july  2023
# NMIP23016 LS Power                         profit and loss  10  july  2023
# NMIP23042 NGUS TLE 2023                    profit and loss  10  july  2023
# NMAP23006 Transgrid-NMA                    profit and loss  10  july  2023
# NMIP23028 Xcel SPC                         profit and loss  10  july  2023
# NMCP22118 ALtalink Bull Wind               profit and loss  30  june  2023
# NMIP23005 Ameren                           profit and loss  30  june  2023
# NMIP22135 Avangrid NYSEG RGE               profit and loss  30  june  2023
# NMIP23014 Avangrid Maine                   profit and loss  30  june  2023
# NMLP23069 Baker Hicks Dunoon               profit and loss  30  june  2023
# NMIP23020 FPL Tx Spring 2023               profit and loss  30  june  2023
# NMCP23017 HONI 2023                        profit and loss  30  june  2023
# NMIP23027 LGE Spring 2023                  profit and loss  30  june  2023
# NMIP23016 LS Power                         profit and loss  30  june  2023
# NMIP23060 Minnkota 2023                    profit and loss  30  june  2023
# NMLP23034 NGUK                             profit and loss  30  june  2023
# NMIP23029 NGUS E5-F6 Mapping               profit and loss  30  june  2023
# NMIP23042 NGUS TLE 2023                    profit and loss  30  june  2023
# NMIP22035 NYPA-NMI                         profit and loss  30  june  2023
# NMIP22135 Avangrid NYSEG RGE-NMI           profit and loss  30  june  2023
# NMIP23005 Ameren-NMI                       profit and loss  30  june  2023
# NMIP23020 FPL TX Spring 2023-NMI           profit and loss  30  june  2023
# NMAP23006 Transgrid-NMA                    profit and loss  30  june  2023
# NMIP22035 NYPA Group A 2022                profit and loss  30  june  2023
# NMIP23035 NYPA Group B                     profit and loss  30  june  2023
# NMIP23019 GPC SoCo VM 2023                 profit and loss  30  june  2023
# NMIP23056 APC SoCo VM 2023                 profit and loss  30  june  2023
# NMLP23057 SSE Fort Augustus                profit and loss  30  june  2023
# NMAP23006 Transgrid 2023                   profit and loss  30  june  2023
# NMIP23026 Xcel Energy SPS 2023 HB          profit and loss  30  june  2023
# NMIP23028 Xcel SPC                         profit and loss  30  june  2023
# NMAP23006 Transgrid 2023                   profit and loss  10  july  2023
# NMAP23006 Transgrid 2023                   profit and loss  30  june  2023
#
# mps_code                                  Currency Converted From  \
# NMCP23017 HONI 2023                            GBP            CAD
# NMCP22118 Altalink Bull trail                  GBP            CAD
# NMIP23020 FPL Tx Spring 2023                   GBP            CAD
# NMCP23017 HONI 2023                            GBP            CAD
# NMIP23042 NGUS TLE 2023                        GBP            USD
# NMIP23035 NYPA Group B                         GBP            USD
# NMIP23019 GPC SoCo VM 2023                     GBP            USD
# NMIP23056 APC SoCo VM 2023                     GBP            USD
# NMCP22118 ALtalink Bull Wind                   GBP            USD
# NMIP23005 Ameren Spring 2023                   GBP            USD
# NMIP22135 Avangrid NYSEG RGE                   GBP            USD
# NMIP23014 Avangrid                             GBP            USD
# NMIP23020 FPL Tx Spring 2023                   GBP            USD
# NMCP23017 HONI 2023                            GBP            USD
# NMIP23027 LGE Spring 2023                      GBP            USD
# NMIP23016 LS Power                             GBP            USD
# NMIP23060 Minnkota 2023                        GBP            USD
# NMIP22126 NGUS Indian River-Lyme Junction      GBP            USD
# NMIP23042 NGUS TLE 2023                        GBP            USD
# NMIP22035 NYPA Group A 2022                    GBP            USD
# NMIP23035 NYPA Group B                         GBP            USD
# NMIP23019 GPC SoCo VM 2023                     GBP            USD
# NMIP23056 APC SoCo VM 2023                     GBP            USD
# NMAP23006 Transgrid 2023                       GBP            USD
# NMIP23026 Xcel Energy SPS 2023 HB              GBP            USD
# NMIP23028 Xcel SPC                             GBP            USD
# NMIP22135 Avangrid NYSEG RGE                   GBP            GBP
# NMIP23016 LS Power                             GBP            GBP
# NMIP23042 NGUS TLE 2023                        GBP            GBP
# NMAP23006 Transgrid-NMA                        GBP            GBP
# NMIP23028 Xcel SPC                             GBP            GBP
# NMCP22118 ALtalink Bull Wind                   GBP            GBP
# NMIP23005 Ameren                               GBP            GBP
# NMIP22135 Avangrid NYSEG RGE                   GBP            GBP
# NMIP23014 Avangrid Maine                       GBP            GBP
# NMLP23069 Baker Hicks Dunoon                   GBP            GBP
# NMIP23020 FPL Tx Spring 2023                   GBP            GBP
# NMCP23017 HONI 2023                            GBP            GBP
# NMIP23027 LGE Spring 2023                      GBP            GBP
# NMIP23016 LS Power                             GBP            GBP
# NMIP23060 Minnkota 2023                        GBP            GBP
# NMLP23034 NGUK                                 GBP            GBP
# NMIP23029 NGUS E5-F6 Mapping                   GBP            GBP
# NMIP23042 NGUS TLE 2023                        GBP            GBP
# NMIP22035 NYPA-NMI                             GBP            GBP
# NMIP22135 Avangrid NYSEG RGE-NMI               GBP            GBP
# NMIP23005 Ameren-NMI                           GBP            GBP
# NMIP23020 FPL TX Spring 2023-NMI               GBP            GBP
# NMAP23006 Transgrid-NMA                        GBP            GBP
# NMIP22035 NYPA Group A 2022                    GBP            GBP
# NMIP23035 NYPA Group B                         GBP            GBP
# NMIP23019 GPC SoCo VM 2023                     GBP            GBP
# NMIP23056 APC SoCo VM 2023                     GBP            GBP
# NMLP23057 SSE Fort Augustus                    GBP            GBP
# NMAP23006 Transgrid 2023                       GBP            GBP
# NMIP23026 Xcel Energy SPS 2023 HB              GBP            GBP
# NMIP23028 Xcel SPC                             GBP            GBP
# NMAP23006 Transgrid 2023                       GBP            AUD
# NMAP23006 Transgrid 2023                       GBP            AUD
#
# mps_code                                   Conversion Rate Project Code  \
# NMCP23017 HONI 2023                                   0.58    NMCP23017
# NMCP22118 Altalink Bull trail                         0.58    NMCP22118
# NMIP23020 FPL Tx Spring 2023                          0.58    NMIP23020
# NMCP23017 HONI 2023                                   0.58    NMCP23017
# NMIP23042 NGUS TLE 2023                               0.76    NMIP23042
# NMIP23035 NYPA Group B                                0.76    NMIP23035
# NMIP23019 GPC SoCo VM 2023                            0.76    NMIP23019
# NMIP23056 APC SoCo VM 2023                            0.76    NMIP23056
# NMCP22118 ALtalink Bull Wind                          0.76    NMCP22118
# NMIP23005 Ameren Spring 2023                          0.76    NMIP23005
# NMIP22135 Avangrid NYSEG RGE                          0.76    NMIP22135
# NMIP23014 Avangrid                                    0.76    NMIP23014
# NMIP23020 FPL Tx Spring 2023                          0.76    NMIP23020
# NMCP23017 HONI 2023                                   0.76    NMCP23017
# NMIP23027 LGE Spring 2023                             0.76    NMIP23027
# NMIP23016 LS Power                                    0.76    NMIP23016
# NMIP23060 Minnkota 2023                               0.76    NMIP23060
# NMIP22126 NGUS Indian River-Lyme Junction             0.76    NMIP22126
# NMIP23042 NGUS TLE 2023                               0.76    NMIP23042
# NMIP22035 NYPA Group A 2022                           0.76    NMIP22035
# NMIP23035 NYPA Group B                                0.76    NMIP23035
# NMIP23019 GPC SoCo VM 2023                            0.76    NMIP23019
# NMIP23056 APC SoCo VM 2023                            0.76    NMIP23056
# NMAP23006 Transgrid 2023                              0.76    NMAP23006
# NMIP23026 Xcel Energy SPS 2023 HB                     0.76    NMIP23026
# NMIP23028 Xcel SPC                                    0.76    NMIP23028
# NMIP22135 Avangrid NYSEG RGE                          1.00    NMIP22135
# NMIP23016 LS Power                                    1.00    NMIP23016
# NMIP23042 NGUS TLE 2023                               1.00    NMIP23042
# NMAP23006 Transgrid-NMA                               1.00    NMAP23006
# NMIP23028 Xcel SPC                                    1.00    NMIP23028
# NMCP22118 ALtalink Bull Wind                          1.00    NMCP22118
# NMIP23005 Ameren                                      1.00    NMIP23005
# NMIP22135 Avangrid NYSEG RGE                          1.00    NMIP22135
# NMIP23014 Avangrid Maine                              1.00    NMIP23014
# NMLP23069 Baker Hicks Dunoon                          1.00    NMLP23069
# NMIP23020 FPL Tx Spring 2023                          1.00    NMIP23020
# NMCP23017 HONI 2023                                   1.00    NMCP23017
# NMIP23027 LGE Spring 2023                             1.00    NMIP23027
# NMIP23016 LS Power                                    1.00    NMIP23016
# NMIP23060 Minnkota 2023                               1.00    NMIP23060
# NMLP23034 NGUK                                        1.00    NMLP23034
# NMIP23029 NGUS E5-F6 Mapping                          1.00    NMIP23029
# NMIP23042 NGUS TLE 2023                               1.00    NMIP23042
# NMIP22035 NYPA-NMI                                    1.00    NMIP22035
# NMIP22135 Avangrid NYSEG RGE-NMI                      1.00    NMIP22135
# NMIP23005 Ameren-NMI                                  1.00    NMIP23005
# NMIP23020 FPL TX Spring 2023-NMI                      1.00    NMIP23020
# NMAP23006 Transgrid-NMA                               1.00    NMAP23006
# NMIP22035 NYPA Group A 2022                           1.00    NMIP22035
# NMIP23035 NYPA Group B                                1.00    NMIP23035
# NMIP23019 GPC SoCo VM 2023                            1.00    NMIP23019
# NMIP23056 APC SoCo VM 2023                            1.00    NMIP23056
# NMLP23057 SSE Fort Augustus                           1.00    NMLP23057
# NMAP23006 Transgrid 2023                              1.00    NMAP23006
# NMIP23026 Xcel Energy SPS 2023 HB                     1.00    NMIP23026
# NMIP23028 Xcel SPC                                    1.00    NMIP23028
# NMAP23006 Transgrid 2023                              0.52    NMAP23006
# NMAP23006 Transgrid 2023                              0.52    NMAP23006
#
# mps_code                                                       Project Name  \
# NMCP23017 HONI 2023                                               HONI 2023
# NMCP22118 Altalink Bull trail                           Altalink Bull trail
# NMIP23020 FPL Tx Spring 2023                             FPL Tx Spring 2023
# NMCP23017 HONI 2023                                               HONI 2023
# NMIP23042 NGUS TLE 2023                                       NGUS TLE 2023
# NMIP23035 NYPA Group B                                         NYPA Group B
# NMIP23019 GPC SoCo VM 2023                                 GPC SoCo VM 2023
# NMIP23056 APC SoCo VM 2023                                 APC SoCo VM 2023
# NMCP22118 ALtalink Bull Wind                             ALtalink Bull Wind
# NMIP23005 Ameren Spring 2023                             Ameren Spring 2023
# NMIP22135 Avangrid NYSEG RGE                             Avangrid NYSEG RGE
# NMIP23014 Avangrid                                                 Avangrid
# NMIP23020 FPL Tx Spring 2023                             FPL Tx Spring 2023
# NMCP23017 HONI 2023                                               HONI 2023
# NMIP23027 LGE Spring 2023                                   LGE Spring 2023
# NMIP23016 LS Power                                                 LS Power
# NMIP23060 Minnkota 2023                                       Minnkota 2023
# NMIP22126 NGUS Indian River-Lyme Junction   NGUS Indian River-Lyme Junction
# NMIP23042 NGUS TLE 2023                                       NGUS TLE 2023
# NMIP22035 NYPA Group A 2022                               NYPA Group A 2022
# NMIP23035 NYPA Group B                                         NYPA Group B
# NMIP23019 GPC SoCo VM 2023                                 GPC SoCo VM 2023
# NMIP23056 APC SoCo VM 2023                                 APC SoCo VM 2023
# NMAP23006 Transgrid 2023                                     Transgrid 2023
# NMIP23026 Xcel Energy SPS 2023 HB                   Xcel Energy SPS 2023 HB
# NMIP23028 Xcel SPC                                                 Xcel SPC
# NMIP22135 Avangrid NYSEG RGE                             Avangrid NYSEG RGE
# NMIP23016 LS Power                                                 LS Power
# NMIP23042 NGUS TLE 2023                                       NGUS TLE 2023
# NMAP23006 Transgrid-NMA                                       Transgrid-NMA
# NMIP23028 Xcel SPC                                                 Xcel SPC
# NMCP22118 ALtalink Bull Wind                             ALtalink Bull Wind
# NMIP23005 Ameren                                                     Ameren
# NMIP22135 Avangrid NYSEG RGE                             Avangrid NYSEG RGE
# NMIP23014 Avangrid Maine                                     Avangrid Maine
# NMLP23069 Baker Hicks Dunoon                             Baker Hicks Dunoon
# NMIP23020 FPL Tx Spring 2023                             FPL Tx Spring 2023
# NMCP23017 HONI 2023                                               HONI 2023
# NMIP23027 LGE Spring 2023                                   LGE Spring 2023
# NMIP23016 LS Power                                                 LS Power
# NMIP23060 Minnkota 2023                                       Minnkota 2023
# NMLP23034 NGUK                                                         NGUK
# NMIP23029 NGUS E5-F6 Mapping                             NGUS E5-F6 Mapping
# NMIP23042 NGUS TLE 2023                                       NGUS TLE 2023
# NMIP22035 NYPA-NMI                                                 NYPA-NMI
# NMIP22135 Avangrid NYSEG RGE-NMI                     Avangrid NYSEG RGE-NMI
# NMIP23005 Ameren-NMI                                             Ameren-NMI
# NMIP23020 FPL TX Spring 2023-NMI                     FPL TX Spring 2023-NMI
# NMAP23006 Transgrid-NMA                                       Transgrid-NMA
# NMIP22035 NYPA Group A 2022                               NYPA Group A 2022
# NMIP23035 NYPA Group B                                         NYPA Group B
# NMIP23019 GPC SoCo VM 2023                                 GPC SoCo VM 2023
# NMIP23056 APC SoCo VM 2023                                 APC SoCo VM 2023
# NMLP23057 SSE Fort Augustus                               SSE Fort Augustus
# NMAP23006 Transgrid 2023                                     Transgrid 2023
# NMIP23026 Xcel Energy SPS 2023 HB                   Xcel Energy SPS 2023 HB
# NMIP23028 Xcel SPC                                                 Xcel SPC
# NMAP23006 Transgrid 2023                                     Transgrid 2023
# NMAP23006 Transgrid 2023                                     Transgrid 2023
#
# mps_code                                   ...  Travel and Subsistence  \
# NMCP23017 HONI 2023                        ...               6167.7490
# NMCP22118 Altalink Bull trail              ...               1777.6710
# NMIP23020 FPL Tx Spring 2023               ...                  0.0000
# NMCP23017 HONI 2023                        ...               2797.9432
# NMIP23042 NGUS TLE 2023                    ...                499.0616
# NMIP23035 NYPA Group B                     ...                108.7104
# NMIP23019 GPC SoCo VM 2023                 ...                  0.0000
# NMIP23056 APC SoCo VM 2023                 ...                  0.0000
# NMCP22118 ALtalink Bull Wind               ...                  0.0000
# NMIP23005 Ameren Spring 2023               ...               1660.2352
# NMIP22135 Avangrid NYSEG RGE               ...                599.3208
# NMIP23014 Avangrid                         ...                918.8856
# NMIP23020 FPL Tx Spring 2023               ...                186.5876
# NMCP23017 HONI 2023                        ...                  0.0000
# NMIP23027 LGE Spring 2023                  ...               1141.4516
# NMIP23016 LS Power                         ...                  0.0000
# NMIP23060 Minnkota 2023                    ...                  0.0000
# NMIP22126 NGUS Indian River-Lyme Junction  ...                  0.0000
# NMIP23042 NGUS TLE 2023                    ...              16210.6936
# NMIP22035 NYPA Group A 2022                ...                  0.0000
# NMIP23035 NYPA Group B                     ...               3891.6940
# NMIP23019 GPC SoCo VM 2023                 ...               1867.3276
# NMIP23056 APC SoCo VM 2023                 ...                  0.0000
# NMAP23006 Transgrid 2023                   ...                  0.0000
# NMIP23026 Xcel Energy SPS 2023 HB          ...                122.9604
# NMIP23028 Xcel SPC                         ...               7907.7164
# NMIP22135 Avangrid NYSEG RGE               ...                  0.0000
# NMIP23016 LS Power                         ...                  0.0000
# NMIP23042 NGUS TLE 2023                    ...                  0.0000
# NMAP23006 Transgrid-NMA                    ...                  0.0000
# NMIP23028 Xcel SPC                         ...                  0.0000
# NMCP22118 ALtalink Bull Wind               ...                  0.0000
# NMIP23005 Ameren                           ...                 66.8500
# NMIP22135 Avangrid NYSEG RGE               ...                984.7500
# NMIP23014 Avangrid Maine                   ...                  0.0000
# NMLP23069 Baker Hicks Dunoon               ...                  0.0000
# NMIP23020 FPL Tx Spring 2023               ...                  0.0000
# NMCP23017 HONI 2023                        ...                  0.0000
# NMIP23027 LGE Spring 2023                  ...                  0.0000
# NMIP23016 LS Power                         ...                  0.0000
# NMIP23060 Minnkota 2023                    ...                  0.0000
# NMLP23034 NGUK                             ...                  0.0000
# NMIP23029 NGUS E5-F6 Mapping               ...                  0.0000
# NMIP23042 NGUS TLE 2023                    ...               2220.5300
# NMIP22035 NYPA-NMI                         ...                  0.0000
# NMIP22135 Avangrid NYSEG RGE-NMI           ...                  0.0000
# NMIP23005 Ameren-NMI                       ...                  0.0000
# NMIP23020 FPL TX Spring 2023-NMI           ...                  0.0000
# NMAP23006 Transgrid-NMA                    ...                  0.0000
# NMIP22035 NYPA Group A 2022                ...                  4.2100
# NMIP23035 NYPA Group B                     ...                  0.0000
# NMIP23019 GPC SoCo VM 2023                 ...                  0.0000
# NMIP23056 APC SoCo VM 2023                 ...                  0.0000
# NMLP23057 SSE Fort Augustus                ...                  0.0000
# NMAP23006 Transgrid 2023                   ...                539.4900
# NMIP23026 Xcel Energy SPS 2023 HB          ...                  0.0000
# NMIP23028 Xcel SPC                         ...                  0.0000
# NMAP23006 Transgrid 2023                   ...                  0.0000
# NMAP23006 Transgrid 2023                   ...                  0.0000
#
# mps_code                                          IS  Salaries - Ops  \
# NMCP23017 HONI 2023                           0.0000          0.0000
# NMCP22118 Altalink Bull trail                 0.0000        637.2808
# NMIP23020 FPL Tx Spring 2023                  0.0000          0.0000
# NMCP23017 HONI 2023                        1045.8560       2867.7636
# NMIP23042 NGUS TLE 2023                       0.0000          0.0000
# NMIP23035 NYPA Group B                        0.0000          0.0000
# NMIP23019 GPC SoCo VM 2023                    0.0000          0.0000
# NMIP23056 APC SoCo VM 2023                    0.0000          0.0000
# NMCP22118 ALtalink Bull Wind                  0.0000          0.0000
# NMIP23005 Ameren Spring 2023                  0.0000          0.0000
# NMIP22135 Avangrid NYSEG RGE                  0.0000        123.6900
# NMIP23014 Avangrid                            0.0000         61.8412
# NMIP23020 FPL Tx Spring 2023                  0.0000       1360.6964
# NMCP23017 HONI 2023                           0.0000         61.8488
# NMIP23027 LGE Spring 2023                     0.0000          0.0000
# NMIP23016 LS Power                            0.0000          0.0000
# NMIP23060 Minnkota 2023                       0.0000        197.4328
# NMIP22126 NGUS Indian River-Lyme Junction     0.0000          0.0000
# NMIP23042 NGUS TLE 2023                      56.2628       2452.5276
# NMIP22035 NYPA Group A 2022                   0.0000          0.0000
# NMIP23035 NYPA Group B                        0.0000          0.0000
# NMIP23019 GPC SoCo VM 2023                    0.0000      11846.6064
# NMIP23056 APC SoCo VM 2023                    0.0000       4455.3556
# NMAP23006 Transgrid 2023                      0.0000        247.3648
# NMIP23026 Xcel Energy SPS 2023 HB             0.0000          0.0000
# NMIP23028 Xcel SPC                           12.1600        123.6900
# NMIP22135 Avangrid NYSEG RGE                  0.0000          0.0000
# NMIP23016 LS Power                            0.0000          0.0000
# NMIP23042 NGUS TLE 2023                     177.0600          0.0000
# NMAP23006 Transgrid-NMA                       0.0000          0.0000
# NMIP23028 Xcel SPC                            0.0000          0.0000
# NMCP22118 ALtalink Bull Wind                  0.0000        389.1000
# NMIP23005 Ameren                              0.0000       2675.9100
# NMIP22135 Avangrid NYSEG RGE                  0.0000       1110.8000
# NMIP23014 Avangrid Maine                      0.0000          0.0000
# NMLP23069 Baker Hicks Dunoon                  0.0000          0.0000
# NMIP23020 FPL Tx Spring 2023                  0.0000       1828.6600
# NMCP23017 HONI 2023                           0.0000        931.8900
# NMIP23027 LGE Spring 2023                     0.0000        267.6800
# NMIP23016 LS Power                            0.0000        439.1700
# NMIP23060 Minnkota 2023                       0.0000          0.0000
# NMLP23034 NGUK                                0.0000        715.3800
# NMIP23029 NGUS E5-F6 Mapping                  0.0000          0.0000
# NMIP23042 NGUS TLE 2023                       0.0000       1969.5600
# NMIP22035 NYPA-NMI                            0.0000          0.0000
# NMIP22135 Avangrid NYSEG RGE-NMI              0.0000          0.0000
# NMIP23005 Ameren-NMI                          0.0000          0.0000
# NMIP23020 FPL TX Spring 2023-NMI              0.0000          0.0000
# NMAP23006 Transgrid-NMA                       0.0000          0.0000
# NMIP22035 NYPA Group A 2022                   0.0000        586.6200
# NMIP23035 NYPA Group B                        0.0000       1136.9900
# NMIP23019 GPC SoCo VM 2023                    0.0000       1840.4300
# NMIP23056 APC SoCo VM 2023                    0.0000       1126.5500
# NMLP23057 SSE Fort Augustus                   0.0000          0.0000
# NMAP23006 Transgrid 2023                      0.0000          0.0000
# NMIP23026 Xcel Energy SPS 2023 HB             0.0000          0.0000
# NMIP23028 Xcel SPC                            0.0000        720.9200
# NMAP23006 Transgrid 2023                      0.0000          0.0000
# NMAP23006 Transgrid 2023                      0.0000          0.0000
#
# mps_code                                   Salaries - Project Management  \
# NMCP23017 HONI 2023                                               0.0000
# NMCP22118 Altalink Bull trail                                     0.0000
# NMIP23020 FPL Tx Spring 2023                                    256.1976
# NMCP23017 HONI 2023                                            1537.1856
# NMIP23042 NGUS TLE 2023                                           0.0000
# NMIP23035 NYPA Group B                                            0.0000
# NMIP23019 GPC SoCo VM 2023                                        0.0000
# NMIP23056 APC SoCo VM 2023                                        0.0000
# NMCP22118 ALtalink Bull Wind                                    228.6384
# NMIP23005 Ameren Spring 2023                                    485.8376
# NMIP22135 Avangrid NYSEG RGE                                      0.0000
# NMIP23014 Avangrid                                                0.0000
# NMIP23020 FPL Tx Spring 2023                                      0.0000
# NMCP23017 HONI 2023                                               0.0000
# NMIP23027 LGE Spring 2023                                       628.7480
# NMIP23016 LS Power                                              114.3192
# NMIP23060 Minnkota 2023                                           0.0000
# NMIP22126 NGUS Indian River-Lyme Junction                         0.0000
# NMIP23042 NGUS TLE 2023                                           0.0000
# NMIP22035 NYPA Group A 2022                                       0.0000
# NMIP23035 NYPA Group B                                          485.8452
# NMIP23019 GPC SoCo VM 2023                                      371.5260
# NMIP23056 APC SoCo VM 2023                                      428.6856
# NMAP23006 Transgrid 2023                                          0.0000
# NMIP23026 Xcel Energy SPS 2023 HB                                 0.0000
# NMIP23028 Xcel SPC                                              657.3164
# NMIP22135 Avangrid NYSEG RGE                                      0.0000
# NMIP23016 LS Power                                                0.0000
# NMIP23042 NGUS TLE 2023                                           0.0000
# NMAP23006 Transgrid-NMA                                           0.0000
# NMIP23028 Xcel SPC                                                0.0000
# NMCP22118 ALtalink Bull Wind                                    171.9000
# NMIP23005 Ameren                                                401.1200
# NMIP22135 Avangrid NYSEG RGE                                    350.3000
# NMIP23014 Avangrid Maine                                        702.0300
# NMLP23069 Baker Hicks Dunoon                                    239.7900
# NMIP23020 FPL Tx Spring 2023                                   2044.0600
# NMCP23017 HONI 2023                                             229.2000
# NMIP23027 LGE Spring 2023                                        76.9200
# NMIP23016 LS Power                                              573.2800
# NMIP23060 Minnkota 2023                                         221.2600
# NMLP23034 NGUK                                                    0.0000
# NMIP23029 NGUS E5-F6 Mapping                                    167.2200
# NMIP23042 NGUS TLE 2023                                         994.6400
# NMIP22035 NYPA-NMI                                                0.0000
# NMIP22135 Avangrid NYSEG RGE-NMI                                  0.0000
# NMIP23005 Ameren-NMI                                              0.0000
# NMIP23020 FPL TX Spring 2023-NMI                                  0.0000
# NMAP23006 Transgrid-NMA                                           0.0000
# NMIP22035 NYPA Group A 2022                                     258.5100
# NMIP23035 NYPA Group B                                          271.8900
# NMIP23019 GPC SoCo VM 2023                                     1694.3800
# NMIP23056 APC SoCo VM 2023                                      136.4100
# NMLP23057 SSE Fort Augustus                                     291.2900
# NMAP23006 Transgrid 2023                                        840.9600
# NMIP23026 Xcel Energy SPS 2023 HB                                60.5300
# NMIP23028 Xcel SPC                                              197.0300
# NMAP23006 Transgrid 2023                                          0.0000
# NMAP23006 Transgrid 2023                                          0.0000
#
# mps_code                                      Aviation       Income  \
# NMCP23017 HONI 2023                             0.0000       0.0000
# NMCP22118 Altalink Bull trail                   0.0000       0.0000
# NMIP23020 FPL Tx Spring 2023                    0.0000       0.0000
# NMCP23017 HONI 2023                             0.0000       0.0000
# NMIP23042 NGUS TLE 2023                         0.0000       0.0000
# NMIP23035 NYPA Group B                          0.0000       0.0000
# NMIP23019 GPC SoCo VM 2023                  53598.9392       0.0000
# NMIP23056 APC SoCo VM 2023                  20295.7316       0.0000
# NMCP22118 ALtalink Bull Wind                    0.0000       0.0000
# NMIP23005 Ameren Spring 2023                60794.6800  219318.0640
# NMIP22135 Avangrid NYSEG RGE                67745.6552   31599.6524
# NMIP23014 Avangrid                           8798.1400   27971.0400
# NMIP23020 FPL Tx Spring 2023                14588.9980   90465.0876
# NMCP23017 HONI 2023                             0.0000       0.0000
# NMIP23027 LGE Spring 2023                   11476.0000  134480.7460
# NMIP23016 LS Power                           8798.1400       0.0000
# NMIP23060 Minnkota 2023                         0.0000       0.0000
# NMIP22126 NGUS Indian River-Lyme Junction    2639.4344       0.0000
# NMIP23042 NGUS TLE 2023                    116908.8392  339786.1200
# NMIP22035 NYPA Group A 2022                 10262.5916  119464.4000
# NMIP23035 NYPA Group B                      29227.2060   93822.0000
# NMIP23019 GPC SoCo VM 2023                      0.0000       0.0000
# NMIP23056 APC SoCo VM 2023                      0.0000       0.0000
# NMAP23006 Transgrid 2023                        0.0000       0.0000
# NMIP23026 Xcel Energy SPS 2023 HB               0.0000       0.0000
# NMIP23028 Xcel SPC                              0.0000       0.0000
# NMIP22135 Avangrid NYSEG RGE                    0.0000       0.0000
# NMIP23016 LS Power                              0.0000       0.0000
# NMIP23042 NGUS TLE 2023                         0.0000       0.0000
# NMAP23006 Transgrid-NMA                         0.0000       0.0000
# NMIP23028 Xcel SPC                              0.0000       0.0000
# NMCP22118 ALtalink Bull Wind                    0.0000       0.0000
# NMIP23005 Ameren                                0.0000       0.0000
# NMIP22135 Avangrid NYSEG RGE                    0.0000       0.0000
# NMIP23014 Avangrid Maine                        0.0000       0.0000
# NMLP23069 Baker Hicks Dunoon                    0.0000       0.0000
# NMIP23020 FPL Tx Spring 2023                    0.0000       0.0000
# NMCP23017 HONI 2023                             0.0000       0.0000
# NMIP23027 LGE Spring 2023                       0.0000       0.0000
# NMIP23016 LS Power                              0.0000       0.0000
# NMIP23060 Minnkota 2023                         0.0000       0.0000
# NMLP23034 NGUK                                  0.0000       0.0000
# NMIP23029 NGUS E5-F6 Mapping                    0.0000       0.0000
# NMIP23042 NGUS TLE 2023                         0.0000       0.0000
# NMIP22035 NYPA-NMI                              0.0000       0.0000
# NMIP22135 Avangrid NYSEG RGE-NMI                0.0000       0.0000
# NMIP23005 Ameren-NMI                            0.0000       0.0000
# NMIP23020 FPL TX Spring 2023-NMI                0.0000       0.0000
# NMAP23006 Transgrid-NMA                         0.0000       0.0000
# NMIP22035 NYPA Group A 2022                     0.0000       0.0000
# NMIP23035 NYPA Group B                          0.0000       0.0000
# NMIP23019 GPC SoCo VM 2023                      0.0000       0.0000
# NMIP23056 APC SoCo VM 2023                      0.0000       0.0000
# NMLP23057 SSE Fort Augustus                     0.0000    5000.0000
# NMAP23006 Transgrid 2023                        0.0000       0.0000
# NMIP23026 Xcel Energy SPS 2023 HB               0.0000       0.0000
# NMIP23028 Xcel SPC                              0.0000       0.0000
# NMAP23006 Transgrid 2023                        0.0000   11648.0000
# NMAP23006 Transgrid 2023                        0.0000  216314.8000
#
# mps_code                                   Internal Trade  Shipping  \
# NMCP23017 HONI 2023                                0.0000    0.0000
# NMCP22118 Altalink Bull trail                      0.0000    0.0000
# NMIP23020 FPL Tx Spring 2023                       0.0000    0.0000
# NMCP23017 HONI 2023                                0.0000    0.0000
# NMIP23042 NGUS TLE 2023                            0.0000    0.0000
# NMIP23035 NYPA Group B                             0.0000    0.0000
# NMIP23019 GPC SoCo VM 2023                         0.0000    0.0000
# NMIP23056 APC SoCo VM 2023                         0.0000    0.0000
# NMCP22118 ALtalink Bull Wind                       0.0000    0.0000
# NMIP23005 Ameren Spring 2023                  126028.5200    0.0000
# NMIP22135 Avangrid NYSEG RGE                   21916.1200    0.0000
# NMIP23014 Avangrid                             16849.9600    0.0000
# NMIP23020 FPL Tx Spring 2023                   59993.0548    0.0000
# NMCP23017 HONI 2023                                0.0000  559.3600
# NMIP23027 LGE Spring 2023                          0.0000    0.0000
# NMIP23016 LS Power                                 0.0000    0.0000
# NMIP23060 Minnkota 2023                            0.0000    0.0000
# NMIP22126 NGUS Indian River-Lyme Junction          0.0000    0.0000
# NMIP23042 NGUS TLE 2023                            0.0000  272.8932
# NMIP22035 NYPA Group A 2022                   107055.1200    0.0000
# NMIP23035 NYPA Group B                         60318.1600    0.0000
# NMIP23019 GPC SoCo VM 2023                         0.0000  662.7200
# NMIP23056 APC SoCo VM 2023                         0.0000    0.0000
# NMAP23006 Transgrid 2023                           0.0000    0.0000
# NMIP23026 Xcel Energy SPS 2023 HB                  0.0000    0.0000
# NMIP23028 Xcel SPC                                 0.0000  588.6428
# NMIP22135 Avangrid NYSEG RGE                       0.0000    0.0000
# NMIP23016 LS Power                                 0.0000    0.0000
# NMIP23042 NGUS TLE 2023                            0.0000    0.0000
# NMAP23006 Transgrid-NMA                        11658.9300    0.0000
# NMIP23028 Xcel SPC                                 0.0000    0.0000
# NMCP22118 ALtalink Bull Wind                       0.0000    0.0000
# NMIP23005 Ameren                                   0.0000    0.0000
# NMIP22135 Avangrid NYSEG RGE                       0.0000    0.0000
# NMIP23014 Avangrid Maine                           0.0000    0.0000
# NMLP23069 Baker Hicks Dunoon                       0.0000    0.0000
# NMIP23020 FPL Tx Spring 2023                       0.0000    0.0000
# NMCP23017 HONI 2023                                0.0000    0.0000
# NMIP23027 LGE Spring 2023                          0.0000    0.0000
# NMIP23016 LS Power                                 0.0000    0.0000
# NMIP23060 Minnkota 2023                            0.0000    0.0000
# NMLP23034 NGUK                                     0.0000    0.0000
# NMIP23029 NGUS E5-F6 Mapping                       0.0000    0.0000
# NMIP23042 NGUS TLE 2023                            0.0000    0.0000
# NMIP22035 NYPA-NMI                            112347.3900    0.0000
# NMIP22135 Avangrid NYSEG RGE-NMI               22797.5800    0.0000
# NMIP23005 Ameren-NMI                          132003.7600    0.0000
# NMIP23020 FPL TX Spring 2023-NMI               62542.7300    0.0000
# NMAP23006 Transgrid-NMA                       162162.2400    0.0000
# NMIP22035 NYPA Group A 2022                        0.0000    0.0000
# NMIP23035 NYPA Group B                         79366.0000    0.0000
# NMIP23019 GPC SoCo VM 2023                         0.0000    0.0000
# NMIP23056 APC SoCo VM 2023                         0.0000    0.0000
# NMLP23057 SSE Fort Augustus                        0.0000    0.0000
# NMAP23006 Transgrid 2023                           0.0000    0.0000
# NMIP23026 Xcel Energy SPS 2023 HB                  0.0000    0.0000
# NMIP23028 Xcel SPC                                 0.0000    0.0000
# NMAP23006 Transgrid 2023                       11648.0000    0.0000
# NMAP23006 Transgrid 2023                      161224.9600    0.0000
#
# mps_code                                   Subcontractors  \
# NMCP23017 HONI 2023                                  0.00
# NMCP22118 Altalink Bull trail                        0.00
# NMIP23020 FPL Tx Spring 2023                         0.00
# NMCP23017 HONI 2023                                  0.00
# NMIP23042 NGUS TLE 2023                              0.00
# NMIP23035 NYPA Group B                               0.00
# NMIP23019 GPC SoCo VM 2023                           0.00
# NMIP23056 APC SoCo VM 2023                           0.00
# NMCP22118 ALtalink Bull Wind                         0.00
# NMIP23005 Ameren Spring 2023                         0.00
# NMIP22135 Avangrid NYSEG RGE                         0.00
# NMIP23014 Avangrid                                   0.00
# NMIP23020 FPL Tx Spring 2023                         0.00
# NMCP23017 HONI 2023                                  0.00
# NMIP23027 LGE Spring 2023                            0.00
# NMIP23016 LS Power                                   0.00
# NMIP23060 Minnkota 2023                              0.00
# NMIP22126 NGUS Indian River-Lyme Junction            0.00
# NMIP23042 NGUS TLE 2023                              0.00
# NMIP22035 NYPA Group A 2022                          0.00
# NMIP23035 NYPA Group B                             733.59
# NMIP23019 GPC SoCo VM 2023                           0.00
# NMIP23056 APC SoCo VM 2023                           0.00
# NMAP23006 Transgrid 2023                             0.00
# NMIP23026 Xcel Energy SPS 2023 HB                    0.00
# NMIP23028 Xcel SPC                                2933.60
# NMIP22135 Avangrid NYSEG RGE                     10074.60
# NMIP23016 LS Power                                 940.32
# NMIP23042 NGUS TLE 2023                            691.50
# NMAP23006 Transgrid-NMA                              0.00
# NMIP23028 Xcel SPC                                1227.53
# NMCP22118 ALtalink Bull Wind                         0.00
# NMIP23005 Ameren                                  5236.05
# NMIP22135 Avangrid NYSEG RGE                       636.24
# NMIP23014 Avangrid Maine                          4519.12
# NMLP23069 Baker Hicks Dunoon                         0.00
# NMIP23020 FPL Tx Spring 2023                      1190.32
# NMCP23017 HONI 2023                                  0.00
# NMIP23027 LGE Spring 2023                        11060.96
# NMIP23016 LS Power                                   0.00
# NMIP23060 Minnkota 2023                              0.00
# NMLP23034 NGUK                                       0.00
# NMIP23029 NGUS E5-F6 Mapping                         0.00
# NMIP23042 NGUS TLE 2023                            396.46
# NMIP22035 NYPA-NMI                                   0.00
# NMIP22135 Avangrid NYSEG RGE-NMI                     0.00
# NMIP23005 Ameren-NMI                                 0.00
# NMIP23020 FPL TX Spring 2023-NMI                     0.00
# NMAP23006 Transgrid-NMA                              0.00
# NMIP22035 NYPA Group A 2022                          0.00
# NMIP23035 NYPA Group B                               0.00
# NMIP23019 GPC SoCo VM 2023                           0.00
# NMIP23056 APC SoCo VM 2023                           0.00
# NMLP23057 SSE Fort Augustus                          0.00
# NMAP23006 Transgrid 2023                             0.00
# NMIP23026 Xcel Energy SPS 2023 HB                    0.00
# NMIP23028 Xcel SPC                                   0.00
# NMAP23006 Transgrid 2023                             0.00
# NMAP23006 Transgrid 2023                             0.00
#
# mps_code                                   Salaries - Production
# NMCP23017 HONI 2023                                         0.00
# NMCP22118 Altalink Bull trail                               0.00
# NMIP23020 FPL Tx Spring 2023                                0.00
# NMCP23017 HONI 2023                                         0.00
# NMIP23042 NGUS TLE 2023                                     0.00
# NMIP23035 NYPA Group B                                      0.00
# NMIP23019 GPC SoCo VM 2023                                  0.00
# NMIP23056 APC SoCo VM 2023                                  0.00
# NMCP22118 ALtalink Bull Wind                                0.00
# NMIP23005 Ameren Spring 2023                                0.00
# NMIP22135 Avangrid NYSEG RGE                                0.00
# NMIP23014 Avangrid                                          0.00
# NMIP23020 FPL Tx Spring 2023                                0.00
# NMCP23017 HONI 2023                                         0.00
# NMIP23027 LGE Spring 2023                                   0.00
# NMIP23016 LS Power                                          0.00
# NMIP23060 Minnkota 2023                                     0.00
# NMIP22126 NGUS Indian River-Lyme Junction                   0.00
# NMIP23042 NGUS TLE 2023                                     0.00
# NMIP22035 NYPA Group A 2022                                 0.00
# NMIP23035 NYPA Group B                                      0.00
# NMIP23019 GPC SoCo VM 2023                                  0.00
# NMIP23056 APC SoCo VM 2023                                  0.00
# NMAP23006 Transgrid 2023                                    0.00
# NMIP23026 Xcel Energy SPS 2023 HB                           0.00
# NMIP23028 Xcel SPC                                          0.00
# NMIP22135 Avangrid NYSEG RGE                                0.00
# NMIP23016 LS Power                                          0.00
# NMIP23042 NGUS TLE 2023                                     0.00
# NMAP23006 Transgrid-NMA                                     0.00
# NMIP23028 Xcel SPC                                          0.00
# NMCP22118 ALtalink Bull Wind                              113.07
# NMIP23005 Ameren                                        10515.50
# NMIP22135 Avangrid NYSEG RGE                            13468.21
# NMIP23014 Avangrid Maine                                 2251.42
# NMLP23069 Baker Hicks Dunoon                              354.63
# NMIP23020 FPL Tx Spring 2023                            12107.73
# NMCP23017 HONI 2023                                        21.18
# NMIP23027 LGE Spring 2023                                7250.17
# NMIP23016 LS Power                                       2291.44
# NMIP23060 Minnkota 2023                                     0.00
# NMLP23034 NGUK                                              0.00
# NMIP23029 NGUS E5-F6 Mapping                                0.00
# NMIP23042 NGUS TLE 2023                                   101.42
# NMIP22035 NYPA-NMI                                          0.00
# NMIP22135 Avangrid NYSEG RGE-NMI                            0.00
# NMIP23005 Ameren-NMI                                        0.00
# NMIP23020 FPL TX Spring 2023-NMI                            0.00
# NMAP23006 Transgrid-NMA                                     0.00
# NMIP22035 NYPA Group A 2022                               658.44
# NMIP23035 NYPA Group B                                   1046.32
# NMIP23019 GPC SoCo VM 2023                               1492.50
# NMIP23056 APC SoCo VM 2023                               2642.06
# NMLP23057 SSE Fort Augustus                                30.60
# NMAP23006 Transgrid 2023                                 2572.46
# NMIP23026 Xcel Energy SPS 2023 HB                         378.72
# NMIP23028 Xcel SPC                                       4480.51
# NMAP23006 Transgrid 2023                                    0.00
# NMAP23006 Transgrid 2023                                    0.00
#
# [59 rows x 21 columns]
